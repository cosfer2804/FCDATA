# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#EDA" data-toc-modified-id="EDA-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#describe,-info" data-toc-modified-id="describe,-info-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>describe, info</a></span></li><li><span><a href="#null-values" data-toc-modified-id="null-values-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>null values</a></span></li><li><span><a href="#check-duplicates" data-toc-modified-id="check-duplicates-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>check duplicates</a></span></li><li><span><a href="#standardize-headers" data-toc-modified-id="standardize-headers-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>standardize headers</a></span></li><li><span><a href="#check-the-target-variable---offer-accepted" data-toc-modified-id="check-the-target-variable---offer-accepted-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>check the target variable - offer accepted</a></span><ul class="toc-item"><li><span><a href="#changing-the-'Yes'-to-1-and-'No'-to-0" data-toc-modified-id="changing-the-'Yes'-to-1-and-'No'-to-0-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>changing the 'Yes' to 1 and 'No' to 0</a></span></li></ul></li></ul></li><li><span><a href="#First-model" data-toc-modified-id="First-model-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>First model</a></span><ul class="toc-item"><li><span><a href="#creating-df1" data-toc-modified-id="creating-df1-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>creating df1</a></span></li><li><span><a href="#fill-the-nulls-with-the-mean" data-toc-modified-id="fill-the-nulls-with-the-mean-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>fill the nulls with the mean</a></span></li><li><span><a href="#split-numerical-and-categorical" data-toc-modified-id="split-numerical-and-categorical-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>split numerical and categorical</a></span></li><li><span><a href="#dealing-with-categorical" data-toc-modified-id="dealing-with-categorical-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>dealing with categorical</a></span></li><li><span><a href="#bring-the-data-together" data-toc-modified-id="bring-the-data-together-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>bring the data together</a></span></li><li><span><a href="#correlation-matrix" data-toc-modified-id="correlation-matrix-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>correlation matrix</a></span></li><li><span><a href="#Applying-the-methods" data-toc-modified-id="Applying-the-methods-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Applying the methods</a></span></li></ul></li><li><span><a href="#Analysis-for-now" data-toc-modified-id="Analysis-for-now-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Analysis for now</a></span></li><li><span><a href="#Ideas" data-toc-modified-id="Ideas-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Ideas</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
sns.set(rc={"figure.figsize":(12.,6.)})
sns.set_style("whitegrid")

# %%
df = pd.read_excel(r'C:\Users\Raphael Costa\Desktop\Thiago\Data Mining\IronHack\GitHub\FCDATA\databases\creditcardmarketing.xlsx')

# %% [markdown]
# # EDA

# %% [markdown]
# ## describe, info

# %%
x = df['Customer Number'].value_counts()
(x>1).value_counts() # drop the customer number - only unique values
# Out:
# False    18000
# Name: Customer Number, dtype: int64

# %%
df= df.drop(['Customer Number'], axis=1)

# %%
df.head(5)
# Out:
#   Offer Accepted     Reward Mailer Type Income Level  # Bank Accounts Open  \
# 0             No  Air Miles      Letter         High                     1
# 1             No  Air Miles      Letter       Medium                     1
# 2             No  Air Miles    Postcard         High                     2
# 3             No  Air Miles      Letter       Medium                     2
# 4             No  Air Miles      Letter       Medium                     1
#
#   Overdraft Protection Credit Rating  # Credit Cards Held  # Homes Owned  \
# 0                   No          High                    2              1
# 1                   No        Medium                    2              2
# 2                   No        Medium                    2              1
# 3                   No          High                    1              1
# 4                   No        Medium                    2              1
#
#    Household Size Own Your Home  Average Balance  Q1 Balance  Q2 Balance  \
# ...

# %%
df.describe()
# Out:
#        # Bank Accounts Open  # Credit Cards Held  # Homes Owned  \
# count          18000.000000         18000.000000   18000.000000
# mean               1.255778             1.903500       1.203444
# std                0.472501             0.797009       0.427341
# min                1.000000             1.000000       1.000000
# 25%                1.000000             1.000000       1.000000
# 50%                1.000000             2.000000       1.000000
# 75%                1.000000             2.000000       1.000000
# max                3.000000             4.000000       3.000000
#
#        Household Size  Average Balance    Q1 Balance    Q2 Balance  \
# count    18000.000000     17976.000000  17976.000000  17976.000000
# mean         3.499056       940.515562    910.450656    999.392190
# std          1.114182       350.297837    620.077060    457.402268
# min          1.000000        48.250000      0.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Offer Accepted        18000 non-null  object
#  1   Reward                18000 non-null  object
#  2   Mailer Type           18000 non-null  object
#  3   Income Level          18000 non-null  object
#  4   # Bank Accounts Open  18000 non-null  int64
#  5   Overdraft Protection  18000 non-null  object
#  6   Credit Rating         18000 non-null  object
#  7   # Credit Cards Held   18000 non-null  int64
#  8   # Homes Owned         18000 non-null  int64
#  9   Household Size        18000 non-null  int64
#  10  Own Your Home         18000 non-null  object
#  11  Average Balance       17976 non-null  float64
#  12  Q1 Balance            17976 non-null  float64
#  13  Q2 Balance            17976 non-null  float64
#  14  Q3 Balance            17976 non-null  float64
# ...

# %% [markdown]
# ## null values
# - 24 empty values in average balance, q1, q2, q3, q4 balance = study them

# %%
df.loc[df['Average Balance'].isnull()]
# Out:
#       Offer Accepted     Reward Mailer Type Income Level  \
# 323               No     Points    Postcard       Medium
# 3070             Yes  Air Miles    Postcard          Low
# 3108              No  Air Miles      Letter          Low
# 3789              No  Air Miles      Letter       Medium
# 5083              No     Points      Letter       Medium
# 5677              No  Air Miles    Postcard          Low
# 5689              No  Air Miles    Postcard       Medium
# 6932              No  Air Miles    Postcard       Medium
# 7787              No  Air Miles      Letter          Low
# 7864              No  Cash Back    Postcard         High
# 8151              No  Cash Back      Letter          Low
# 8634              No  Air Miles    Postcard         High
# 10039             No  Cash Back    Postcard       Medium
# 10860             No     Points      Letter       Medium
# 12479             No     Points      Letter       Medium
# ...

# %%
df['Average Balance'].isnull().value_counts()
# Out:
# False    17976
# True        24
# Name: Average Balance, dtype: int64

# %% [markdown]
# ## check duplicates
# - no duplicates

# %%
dupli = df.duplicated()
dupli.unique()
# Out:
# array([False])

# %% [markdown]
# ## standardize headers

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Offer Accepted, Reward, Mailer Type, Income Level, # Bank Accounts Open, Overdraft Protection, Credit Rating, # Credit Cards Held, # Homes Owned, Household Size, Own Your Home, Average Balance, Q1 Balance, Q2 Balance, Q3 Balance, Q4 Balance]
# Index: []

# %% [markdown]
# - all of them lowercase without space ('_'), without '#'
# - change column name to: accounts_open

# %%
new_names={'# Bank Accounts Open' : 'Accounts Open', '# Credit Cards Held' : 'Credit Cards Held', '# Homes Owned' : 'Homes Owned' }

# %%
df.rename(columns=new_names, inplace=True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Offer Accepted, Reward, Mailer Type, Income Level, Accounts Open, Overdraft Protection, Credit Rating, Credit Cards Held, Homes Owned, Household Size, Own Your Home, Average Balance, Q1 Balance, Q2 Balance, Q3 Balance, Q4 Balance]
# Index: []

# %%
cols=[]
for i in range(len(df.columns)):
    cols.append(df.columns[i].lower().replace(' ','_'))
df.columns=cols
df.head(0)
# Out:
# Empty DataFrame
# Columns: [offer_accepted, reward, mailer_type, income_level, accounts_open, overdraft_protection, credit_rating, credit_cards_held, homes_owned, household_size, own_your_home, average_balance, q1_balance, q2_balance, q3_balance, q4_balance]
# Index: []

# %% [markdown]
# ## check the target variable - offer accepted
# - imbalanced data, will be necessary oversampling or undersampling

# %%
df['offer_accepted'].value_counts()
# Out:
# No     16977
# Yes     1023
# Name: offer_accepted, dtype: int64

# %% [markdown]
# ### changing the 'Yes' to 1 and 'No' to 0

# %%
df['offer_accepted']= df.offer_accepted.map(dict(Yes=1, No=0))

# %%
df['offer_accepted'].value_counts()
# Out:
# 0    16977
# 1     1023
# Name: offer_accepted, dtype: int64

# %% [markdown]
# # First model
# - for the first attempt we are going to fill the nulls with the avg
# - apply a for  to test different methods and comparing accuracy of them;

# %% [markdown]
# ## creating df1
# - filling with the average of each columns. The average_balance will be filled with the avg of the mean of q1,q2,q3,q4.
# - and also will drop the column average_balance, because it's the average of the quarters columns.

# %%
df1 = df

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   offer_accepted        18000 non-null  int64
#  1   reward                18000 non-null  object
#  2   mailer_type           18000 non-null  object
#  3   income_level          18000 non-null  object
#  4   accounts_open         18000 non-null  int64
#  5   overdraft_protection  18000 non-null  object
#  6   credit_rating         18000 non-null  object
#  7   credit_cards_held     18000 non-null  int64
#  8   homes_owned           18000 non-null  int64
#  9   household_size        18000 non-null  int64
#  10  own_your_home         18000 non-null  object
#  11  average_balance       17976 non-null  float64
#  12  q1_balance            17976 non-null  float64
#  13  q2_balance            17976 non-null  float64
#  14  q3_balance            17976 non-null  float64
# ...

# %% [markdown]
# ## fill the nulls with the mean

# %%
mean_q1 = df1['q1_balance'].loc[df1['q1_balance'].notnull()].median()
mean_q2 = df1['q2_balance'].loc[df1['q2_balance'].notnull()].median()
mean_q3 = df1['q3_balance'].loc[df1['q3_balance'].notnull()].median()
mean_q4 = df1['q4_balance'].loc[df1['q4_balance'].notnull()].median()
mean_balance = (mean_q1+mean_q2+mean_q3+mean_q4)/4

# %%
df1['average_balance']=df1['average_balance'].fillna(mean_balance)
df1['q1_balance']=df1['q1_balance'].fillna(mean_q1)
df1['q2_balance']=df1['q2_balance'].fillna(mean_q2)
df1['q3_balance']=df1['q3_balance'].fillna(mean_q3)
df1['q4_balance']=df1['q4_balance'].fillna(mean_q4)

# %%
df1 = df1.drop(['average_balance'], axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   offer_accepted        18000 non-null  int64
#  1   reward                18000 non-null  object
#  2   mailer_type           18000 non-null  object
#  3   income_level          18000 non-null  object
#  4   accounts_open         18000 non-null  int64
#  5   overdraft_protection  18000 non-null  object
#  6   credit_rating         18000 non-null  object
#  7   credit_cards_held     18000 non-null  int64
#  8   homes_owned           18000 non-null  int64
#  9   household_size        18000 non-null  int64
#  10  own_your_home         18000 non-null  object
#  11  q1_balance            18000 non-null  float64
#  12  q2_balance            18000 non-null  float64
#  13  q3_balance            18000 non-null  float64
#  14  q4_balance            18000 non-null  float64
# ...

# %% [markdown]
# ## split numerical and categorical
# - without splitting the target (offer_accepted)

# %%
df1_num=df1.select_dtypes(include=np.number) # OR include=number
df1_cat=df1.select_dtypes(exclude=np.number)# OR include=object

# %%
df1_num.head(1)
# Out:
#    offer_accepted  accounts_open  credit_cards_held  homes_owned  \
# 0               0              1                  2            1
#
#    household_size  q1_balance  q2_balance  q3_balance  q4_balance
# 0               4      1669.0       877.0      1095.0      1002.0

# %%
df1_cat.head(1)
# Out:
#       reward mailer_type income_level overdraft_protection credit_rating  \
# 0  Air Miles      Letter         High                   No          High
#
#   own_your_home
# 0            No

# %% [markdown]
# ## dealing with categorical

# %%
df1_cat_dummies=pd.get_dummies(df1_cat, drop_first=True)

# %%
df1_cat_dummies.head(1)
# Out:
#    reward_Cash Back  reward_Points  mailer_type_Postcard  income_level_Low  \
# 0                 0              0                     0                 0
#
#    income_level_Medium  overdraft_protection_Yes  credit_rating_Low  \
# 0                    0                         0                  0
#
#    credit_rating_Medium  own_your_home_Yes
# 0                     0                  0

# %% [markdown]
# ## bring the data together

# %%
df1_full=pd.concat([df1_cat_dummies,df1_num],axis=1)

# %%
df1_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   reward_Cash Back          18000 non-null  uint8
#  1   reward_Points             18000 non-null  uint8
#  2   mailer_type_Postcard      18000 non-null  uint8
#  3   income_level_Low          18000 non-null  uint8
#  4   income_level_Medium       18000 non-null  uint8
#  5   overdraft_protection_Yes  18000 non-null  uint8
#  6   credit_rating_Low         18000 non-null  uint8
#  7   credit_rating_Medium      18000 non-null  uint8
#  8   own_your_home_Yes         18000 non-null  uint8
#  9   offer_accepted            18000 non-null  int64
#  10  accounts_open             18000 non-null  int64
#  11  credit_cards_held         18000 non-null  int64
#  12  homes_owned               18000 non-null  int64
#  13  household_size            18000 non-null  int64
# ...

# %% [markdown]
# ## correlation matrix

# %%
corre_matrix=df1_full.corr()
mask=np.zeros_like(corre_matrix)
mask[np.triu_indices_from(mask)]=True
fig, ax = plt.subplots(figsize=(20,10))
ax=sns.heatmap(corre_matrix, mask=mask, annot=True, cmap=sns.diverging_palette(20, 220, n=2000));

# %% [markdown]
# ## Applying the methods

# %%
y = df1_full['offer_accepted']
X1 = df1_full.drop(['offer_accepted'], axis=1)

# %%
from sklearn.pipeline import Pipeline
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
import xgboost as xgb
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import metrics
from sklearn.model_selection import KFold, cross_val_score

# %%
KFold_Score = pd.DataFrame()
classifiers = ['LogisticRegression', 'RandomForestClassifier', 'KNeighborsClassifier','GradientBoostingClassifier']
models = [
          LogisticRegression(max_iter = 3000),
          RandomForestClassifier(n_estimators=200, random_state=0),
          KNeighborsClassifier(),
          GradientBoostingClassifier(random_state=0)
         ]
j = 0
for i in models:
    model = i
    cv = KFold(n_splits=5, random_state=0, shuffle=True)
    KFold_Score[classifiers[j]] = (cross_val_score(model, X1, np.ravel(y), scoring = 'accuracy', cv=cv))
    j = j+1
# Out:
# C:\Users\Raphael Costa\anaconda3\envs\class1\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Raphael Costa\anaconda3\envs\class1\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
mean = pd.DataFrame(KFold_Score.mean(), index= classifiers)
KFold_Score = pd.concat([KFold_Score,mean.T])
KFold_Score.index=['Fold 1','Fold 2','Fold 3','Fold 4','Fold 5','Mean']
KFold_Score.T.sort_values(by=['Mean'], ascending = False)
# Out:
#                               Fold 1    Fold 2    Fold 3    Fold 4    Fold 5  \
# LogisticRegression          0.938889  0.939722  0.945556  0.947778  0.943889
# RandomForestClassifier      0.938611  0.939444  0.945000  0.947500  0.943889
# GradientBoostingClassifier  0.938611  0.939444  0.944722  0.947500  0.943889
# KNeighborsClassifier        0.935000  0.937500  0.945000  0.947222  0.943333
#
#                                 Mean
# LogisticRegression          0.943167
# RandomForestClassifier      0.942889
# GradientBoostingClassifier  0.942833
# KNeighborsClassifier        0.941611

# %% [markdown]
# # Analysis for now
# - standardize headers - ok
# - correlation matrix = see any relations - ok
# - some plots to understand the outliers, histograms
# - deal with outliers
#
#
# # Ideas
# - apply logistic regression, decision tree, KNN - check witch scalers is going to be the best one to use it.
